# %% [markdown]
# # Police Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_excel(r'police.xlsx')

# %%
data1
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0        1.2.2005  01:55:00          NaN             M          1985.0
# 1       1.18.2005  08:15:00          NaN             M          1965.0
# 2       1.23.2005  23:15:00          NaN             M          1972.0
# 3       2.20.2005  17:15:00          NaN             M          1986.0
# 4       3.14.2005  10:00:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  12.31.2015  20:27:00          NaN             M          1986.0
# 91737  12.31.2015  20:35:00          NaN             F          1982.0
# 91738  12.31.2015  20:45:00          NaN             M          1992.0
# 91739  12.31.2015  21:42:00          NaN             M          1993.0
# 91740  12.31.2015  22:46:00          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
data1
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0        1.2.2005  01:55:00          NaN             M          1985.0
# 1       1.18.2005  08:15:00          NaN             M          1965.0
# 2       1.23.2005  23:15:00          NaN             M          1972.0
# 3       2.20.2005  17:15:00          NaN             M          1986.0
# 4       3.14.2005  10:00:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  12.31.2015  20:27:00          NaN             M          1986.0
# 91737  12.31.2015  20:35:00          NaN             F          1982.0
# 91738  12.31.2015  20:45:00          NaN             M          1992.0
# 91739  12.31.2015  21:42:00          NaN             M          1993.0
# 91740  12.31.2015  22:46:00          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
sns.boxplot(x="driver_age", data=data1)
# Out:
# <Axes: xlabel='driver_age'>

# %%
data1.dtypes
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested           float64
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
data1.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
missing_percent = (data1.isnull().sum() / len(data1))*100
missing_percent
# Out:
# stop_date               0.000000
# stop_time               0.000000
# county_name           100.000000
# driver_gender           5.815284
# driver_age_raw          5.806564
# driver_age              6.127032
# driver_race             5.813104
# violation_raw           5.813104
# violation               5.813104
# search_conducted        0.000000
# search_type            96.516280
# stop_outcome            5.813104
# is_arrested             5.813104
# stop_duration           5.813104
# drugs_related_stop      0.000000
# dtype: float64

# %%
for i in data1.columns:
    if missing_percent[i]>90:
        print(i)
# Out:
# county_name
# search_type

# %%
for i in data1.columns:
    if missing_percent[i]>90:
        data1.drop(i, axis=1, inplace=True)

# %%
data1.columns
# Out:
# Index(['stop_date', 'stop_time', 'driver_gender', 'driver_age_raw',
#        'driver_age', 'driver_race', 'violation_raw', 'violation',
#        'search_conducted', 'stop_outcome', 'is_arrested', 'stop_duration',
#        'drugs_related_stop'],
#       dtype='object')

# %%
data1.drop('county_name',axis=1,inplace=True)

# %%
data1.drop('search_type',axis=1,inplace=True)

# %%
# drop several columns together

data1.drop(['county_name','search_type'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-d25526dd7e51> in <module>
#       1 # drop several columns together
#       2
# ----> 3 data1.drop(['county_name','search_type'], axis=1, inplace=True)
#
# C:\py\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# C:\py\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
data1[['driver_gender', 'driver_race']] = data1[['driver_gender', 'driver_race']].fillna('Unknown')

# %%
data1['driver_age'].fillna(value=data1['driver_age'].mean(), inplace=True)

# %%
data1.isnull().sum()
# Out:
# stop_date                0
# stop_time                0
# driver_gender            0
# driver_age_raw        5327
# driver_age               0
# driver_race              0
# violation_raw         5333
# violation             5333
# search_conducted         0
# stop_outcome          5333
# is_arrested           5333
# stop_duration         5333
# drugs_related_stop       0
# dtype: int64

# %%
violations = data1["violation_raw"].value_counts()
violations
# Out:
# Speeding                            48463
# Other Traffic Violation             16224
# Equipment/Inspection Violation      11020
# Registration Violation               3432
# Seatbelt Violation                   2952
# Special Detail/Directed Patrol       2455
# Call for Service                     1298
# Violation of City/Town Ordinance      211
# Motorist Assist/Courtesy              203
# APB                                    79
# Suspicious Person                      56
# Warrant                                15
# Name: violation_raw, dtype: int64

# %%
data1.stop_outcome.value_counts()
# Out:
# Citation            77006
# Warning              5294
# Arrest Driver        2571
# N/D                   590
# No Action             589
# Arrest Passenger      358
# Name: stop_outcome, dtype: int64

# %%
arrested = data1[data1['stop_outcome'] == 'Arrest Driver']

# %%
arrested
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 3       2.20.2005     17:15             M          1986.0        19.0
# 22       8.8.2005      2:09             M          1955.0        50.0
# 24      8.28.2005      1:00             M          1979.0        26.0
# 31      9.28.2005      6:20             M          1982.0        23.0
# 40      10.1.2005      0:00             M          1988.0        17.0
# ...           ...       ...           ...             ...         ...
# 91297   12.8.2015      1:30             M          1994.0        21.0
# 91386  12.12.2015     20:00             M          1973.0        42.0
# 91471  12.16.2015     14:52             M          1975.0        40.0
# 91625  12.26.2015     23:18             M          1969.0        46.0
# 91628  12.27.2015      0:27             M          1987.0        28.0
#
#       driver_race                   violation_raw            violation  \
# ...

# %%
sns.countplot(x='driver_gender',data=data1)

# %%
male = arrested[arrested["driver_gender"] == "M"]

# %%
male["driver_age"].mean()
# Out:
# 32.050890473631654

# %%
oldest_male = male[male["driver_age"] == male["driver_age"].max()]
oldest_male
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 32835  2.25.2009     15:41             M          1930.0        79.0
#
#       driver_race            violation_raw         violation  \
# 32835       White  Other Traffic Violation  Moving violation
#
#        search_conducted   stop_outcome is_arrested stop_duration  \
# 32835              True  Arrest Driver        True      0-15 Min
#
#        drugs_related_stop
# 32835               False
